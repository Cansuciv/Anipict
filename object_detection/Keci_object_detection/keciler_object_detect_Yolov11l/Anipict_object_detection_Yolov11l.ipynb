# %% [markdown]
# # ANIPICT Nesne Tanıma

# %% [markdown]
# ## Ortam Hazırlığı

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/Anipict/object_detection
# Out:
# /content/drive/MyDrive/Anipict/object_detection

# %%
#ultralytics'i indirme.
# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.102 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 40.9/112.6 GB disk)

# %% [markdown]
# ## Training

# %%
# !unzip data/keciler_dataset.zip -d ./data
# Out:
# Archive:  data/keciler_dataset.zip
#    creating: ./data/keciler_dataset/
#   inflating: ./data/keciler_dataset/data.yaml
#   inflating: ./data/keciler_dataset/README.dataset.txt
#   inflating: ./data/keciler_dataset/README.roboflow.txt
#    creating: ./data/keciler_dataset/test/
#    creating: ./data/keciler_dataset/test/images/
#   inflating: ./data/keciler_dataset/test/images/AnkaraKecisi29_jpg.rf.d6980147513400d314e2d6ee1dcd45cd.jpg
#   inflating: ./data/keciler_dataset/test/images/AnkaraKecisi35_jpg.rf.75728852726c73b3bb691146eb1e9e92.jpg
#   inflating: ./data/keciler_dataset/test/images/AnkaraKecisi40_jpg.rf.94c9845ffe52c1f5a607c4969931f196.jpg
#   inflating: ./data/keciler_dataset/test/images/AnkaraKecisi54_jpg.rf.969f893be359dcc85ea741ea366f435b.jpg
#   inflating: ./data/keciler_dataset/test/images/AnkaraKecisi71_jpg.rf.39030de6c265ca5fbdefb427577ccf48.jpg
#   inflating: ./data/keciler_dataset/test/images/AnkaraKecisi78_png.rf.1b2ebda48c57e9620bd8a1c25d675a01.jpg
# ...

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Anipict/object_detection'

# %%
# !yolo detect train data=data/data.yaml model=yolo11l.pt epochs=100 imgsz=640 workers=8 batch=8 device=0 name=yolov8_anipict_detection
# Out:
# ...
# 100% 49.0M/49.0M [00:00<00:00, 184MB/s]
# Ultralytics 8.3.101 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Anipict/object_detection'

# %%
# yarıda kalmış/kesilmiş eğitimi devam ettirme
# !yolo detect train model=runs/detect/yolov8_anipict_detection/weights/last.pt resume=True
# Out:
# Ultralytics 8.3.101 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# ## keçi Tespiti / Prediction

# %%
# !yolo detect predict model=runs/detect/yolov8_anipict_detection/weights/best.pt source=inference save=True
# Out:
# Ultralytics 8.3.101 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11l summary (fused): 190 layers, 25,286,251 parameters, 0 gradients, 86.6 GFLOPs
#
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/cfg/__init__.py", line 987, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py", line 550, in predict
#     return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/predictor.py", line 236, in predict_cli
#     for _ in gen:  # sourcery skip: remove-empty-nested-block, noqa
# ...

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Anipict/object_detection'

# %%
import cv2
import imutils
from ultralytics import YOLO
from google.colab.patches import cv2_imshow

font= cv2.FONT_HERSHEY_SIMPLEX

img_path = "deneme-resimler/YabanKecisi.jpg"
model_path = "runs/detect/yolov8_anipict_detection/weights/best.pt"

img = cv2.imread(img_path)
img = imutils.resize(img, width=640)
model = YOLO(model_path)

results = model(img)[0]
#print(results)

threshold = 0.5
for result in results.boxes.data.tolist():
  x1, y1, x2, y2, score, class_id = result
  x1, y1, x2, y2, class_id = int(x1), int(y1), int(x2), int(y2), int(class_id)

  # print(result)
  if score > threshold:
    cv2.rectangle(img, (x1,y1), (x2,y2), (0,255,0), 2)

    class_name = results.names[class_id]
    score = score * 100
    text = f"{class_name}: %{score:.2f}"
    cv2.putText(img, text, (x1, y1-10), font, 0.5, (0,255,0), 1, cv2.LINE_AA)

cv2_imshow(img)

# inference içindeki tüm resimleri tara ve çıktıları bastır (for döngüsü ile tarayacağız ve çıktıları alt alta bastıracağız)
# Tüm resimler için bir adres üretmemiz gerekiyor (glob, os) kullanarak bir adresteki tüm dosyaları tarayabiliriz.
# Out:
# 0: 448x640 1 Yaban Keçisi, 36.7ms
# Speed: 1.5ms preprocess, 36.7ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=640x425>
